# %%
import  pandas as pd

# %%
df = pd.read_csv("ommart_medicines.csv")

# %%
df.head()
# Out:
#    product_id               product_name category       brand  price_inr
# 0           1   Paracetamol 500mg Tablet   Tablet       Cipla         25
# 1           2            Dolo 650 Tablet   Tablet  Micro Labs         30
# 2           3      Crocin Advance Tablet   Tablet         GSK         28
# 3           4  Azithromycin 500mg Tablet   Tablet  Sun Pharma         95
# 4           5  Amoxicillin 500mg Capsule  Capsule     Mankind         85

# %%
df.tail()
# Out:
#     product_id             product_name category       brand  price_inr
# 20          21   Thyroxine 50mcg Tablet   Tablet      Abbott         48
# 21          22  Clopidogrel 75mg Tablet   Tablet  Dr Reddy's         82
# 22          23  Telmisartan 40mg Tablet   Tablet     Mankind         68
# 23          24  Montelukast 10mg Tablet   Tablet       Cipla         58
# 24          25        Folic Acid Tablet   Tablet       Zydus         20

# %%
df
# Out:
#     product_id                product_name    category       brand  price_inr
# 0            1    Paracetamol 500mg Tablet      Tablet       Cipla         25
# 1            2             Dolo 650 Tablet      Tablet  Micro Labs         30
# 2            3       Crocin Advance Tablet      Tablet         GSK         28
# 3            4   Azithromycin 500mg Tablet      Tablet  Sun Pharma         95
# 4            5   Amoxicillin 500mg Capsule     Capsule     Mankind         85
# 5            6      Ibuprofen 400mg Tablet      Tablet      Abbott         35
# 6            7      Metformin 500mg Tablet      Tablet         USV         40
# 7            8       Amlodipine 5mg Tablet      Tablet  Dr Reddy's         55
# 8            9    Pantoprazole 40mg Tablet      Tablet       Cipla         60
# 9           10      Cetirizine 10mg Tablet      Tablet    Glenmark         22
# 10          11   Levocetirizine 5mg Tablet      Tablet       Intas         24
# 11          12      Vitamin C 500mg Tablet  Supplement    Himalaya         45
# 12          13  Calcium + Vitamin D Tablet  Supplement   HealthVit        120
# 13          14           ORS Powder Sachet  Supplement       Dabur         18
# 14          15              Disprin Tablet      Tablet     Reckitt         15
# 15          16     Ranitidine 150mg Tablet      Tablet  Sun Pharma         32
# 16          17     Domperidone 10mg Tablet      Tablet       Cipla         42
# 17          18    Atorvastatin 10mg Tablet      Tablet       Zydus         75
# 18          19        Losartan 50mg Tablet      Tablet       Alkem         65
# 19          20         Multivitamin Tablet  Supplement     Revital        150
# 20          21      Thyroxine 50mcg Tablet      Tablet      Abbott         48
# 21          22     Clopidogrel 75mg Tablet      Tablet  Dr Reddy's         82
# 22          23     Telmisartan 40mg Tablet      Tablet     Mankind         68
# 23          24     Montelukast 10mg Tablet      Tablet       Cipla         58
# 24          25           Folic Acid Tablet      Tablet       Zydus         20

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.product_id , df.price_inr)
plt.xlabel("Product-id")
plt.ylabel("Prices")
plt.tight_layout()
plt.grid(True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    25 non-null     int64
#  1   product_name  25 non-null     object
#  2   category      25 non-null     object
#  3   brand         25 non-null     object
#  4   price_inr     25 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#        product_id   price_inr
# count   25.000000   25.000000
# mean    13.000000   53.480000
# std      7.359801   33.599504
# min      1.000000   15.000000
# 25%      7.000000   28.000000
# 50%     13.000000   45.000000
# 75%     19.000000   68.000000
# max     25.000000  150.000000

# %%
df.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# brand           0
# price_inr       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.loc[df['price_inr'].idxmax()]
# Out:
# product_id                       20
# product_name    Multivitamin Tablet
# category                 Supplement
# brand                       Revital
# price_inr                       150
# Name: 19, dtype: object

# %%
df.loc[df['price_inr'].idxmin()]
# Out:
# product_id                  15
# product_name    Disprin Tablet
# category                Tablet
# brand                  Reckitt
# price_inr                   15
# Name: 14, dtype: object

# %%
df.head()
# Out:
#    product_id               product_name category       brand  price_inr
# 0           1   Paracetamol 500mg Tablet   Tablet       Cipla         25
# 1           2            Dolo 650 Tablet   Tablet  Micro Labs         30
# 2           3      Crocin Advance Tablet   Tablet         GSK         28
# 3           4  Azithromycin 500mg Tablet   Tablet  Sun Pharma         95
# 4           5  Amoxicillin 500mg Capsule  Capsule     Mankind         85

# %%
x = df[['category' , 'brand']]
y = df['price_inr']

# %%
x.head()
# Out:
#   category       brand
# 0   Tablet       Cipla
# 1   Tablet  Micro Labs
# 2   Tablet         GSK
# 3   Tablet  Sun Pharma
# 4  Capsule     Mankind

# %%
y.head()
# Out:
# 0    25
# 1    30
# 2    28
# 3    95
# 4    85
# Name: price_inr, dtype: int64

# %%
x = pd.get_dummies(x , drop_first=True) #ONEHOT ENCODING

# %%
x.head()
# Out:
#    category_Supplement  category_Tablet  brand_Alkem  brand_Cipla  \
# 0                False             True        False         True
# 1                False             True        False        False
# 2                False             True        False        False
# 3                False             True        False        False
# 4                False            False        False        False
#
#    brand_Dabur  brand_Dr Reddy's  brand_GSK  brand_Glenmark  brand_HealthVit  \
# 0        False             False      False           False            False
# 1        False             False      False           False            False
# 2        False             False       True           False            False
# 3        False             False      False           False            False
# 4        False             False      False           False            False
#
#    brand_Himalaya  brand_Intas  brand_Mankind  brand_Micro Labs  \
# 0           False        False          False             False
# 1           False        False          False              True
# 2           False        False          False             False
# 3           False        False          False             False
# 4           False        False           True             False
#
#    brand_Reckitt  brand_Revital  brand_Sun Pharma  brand_USV  brand_Zydus
# 0          False          False             False      False        False
# 1          False          False             False      False        False
# 2          False          False             False      False        False
# 3          False          False              True      False        False
# 4          False          False             False      False        False

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test ,y_train , y_test = train_test_split(x ,y , test_size=0.2 , random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([41.5  , 41.5  , 41.5  , 41.5  , 86.625])

# %%
y_test
# Out:
# 8     60
# 16    42
# 0     25
# 23    58
# 11    45
# Name: price_inr, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test , prediction)
# Out:
# 18.72500000000001
